# %%
# Basic plots: 

#https://matplotlibguide.readthedocs.io/en/latest/Matplotlib/basic.html

# %%
import matplotlib.pyplot as plt # for plots display 
import numpy as np #numpy has sin and cos function

# %%
#5 functions 

#linspace(a,b,total_points)
x= np.linspace(2,8,4)
print("x:" ,x)

#sin(x)

sinx=np.sin(x) # x is considered in radian 
print("sinx:" ,sinx)

#cos(x)

cosx=np.cos(x)
print("cosx:" ,cosx)


#rand : uniform random variables 

ur= np.random.rand(4)
print("uniform random variables:", ur)

#randn= normal random variables

nr= np.random.randn(4)
print("normal random variables:", nr)
# Out:
# [ 1.          1.18367347  1.36734694  1.55102041  1.73469388  1.91836735
#   2.10204082  2.28571429  2.46938776  2.65306122  2.83673469  3.02040816
#   3.20408163  3.3877551   3.57142857  3.75510204  3.93877551  4.12244898
#   4.30612245  4.48979592  4.67346939  4.85714286  5.04081633  5.2244898
#   5.40816327  5.59183673  5.7755102   5.95918367  6.14285714  6.32653061
#   6.51020408  6.69387755  6.87755102  7.06122449  7.24489796  7.42857143
#   7.6122449   7.79591837  7.97959184  8.16326531  8.34693878  8.53061224
#   8.71428571  8.89795918  9.08163265  9.26530612  9.44897959  9.63265306
#   9.81632653 10.        ]
# x: [2. 4. 6. 8.]
# sinx: [ 0.90929743 -0.7568025  -0.2794155   0.98935825]
# cosx: [-0.41614684 -0.65364362  0.96017029 -0.14550003]
# uniform random variables: [0.36936954 0.87562131 0.60623389 0.22283822]
# normal random variables: [ 0.97838392  1.16050111 -0.37454241  0.21786233]

# %%
#Basic plots

# %%
#plot 1

x=np.linspace(-2*np.pi,2*np.pi,100) # 100 euidistant points in the range[-2pi,2pi]

######################sinx#################
sinx= np.sin(x)
plt.plot(x,sinx,label='sin') # plot x on x axis and sinx on y axis 

#legend and label and Grid 

############Legend#################
#label in plt.plot are displayed by legend command 

#show legend

plt.legend(loc="best") #loc= "best" parameter finds the best place for the legend

##########Label and Grid #############

plt.xlabel("Radian") #x Label
plt.ylabel("Amplitude") # ylabel 


plt.grid() # show grid

plt.show() # display the plot

# %%
#line style and Marker

plt.plot(x,sinx,color='m',
         linestyle='-',linewidth=4,marker='o',
         markeredgewidth=3,markersize=5,label='sin'
        )

# %%
#plot2 


x=np.linspace(-2*np.pi,2*np.pi,100)

sinx=np.sin(x)

###########line style and marker#############

plt.plot(x,sinx,'*--r',markersize=10,label='sin')

###########legend########################

plt.legend(loc='best') #show legend 

##########label and Grid#############

plt.xlabel("Radian") #x label 
plt.ylabel("Amplitude") #y label 

plt.grid()

plt.show()

# %%
#plot3

############ Sin(x) ####################
x=np.linspace(-2*np.pi, 2*np.pi, 100) 
sinx=np.sin(x) # calculate sin(x)

########### Line style and Marker ###################
plt.plot(x,sinx, '*--r', markersize=10, label='sin')  

############ Legend ####################
plt.legend(loc="best") #show legend

#### Lable and Grid ####################
plt.xlabel("Radian") # x label 
plt.ylabel("Amplitude") # y label
plt.grid() # show grid

############ Axis Limit and Marker ##################
# x-axis and y-axis limits
plt.xlim([-2*np.pi, 2*np.pi]) # x-axis display range
plt.ylim([-1.5, 1.5]) # y-axis display range

# ticks on the axis
# display ticks in pi format rather than 3.14 format
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],
          [r'$-2\pi$', r'$-\pi$', r'$0$', r'$+\pi$', r'2$\pi$'])
plt.yticks([-1, 0, +1])

################## Title #########################
plt.title("Plot $Sin(x)$")

plt.show()

# %%
#Multiple Plots

#multiplot.py
import numpy as np
import matplotlib.pyplot as plt

# close all the figures, if open from previous commands
plt.close('all') 

############ Sin(x) ####################
x=np.linspace(-2*np.pi, 2*np.pi, 100) 
sinx=np.sin(x) # calculate sin(x)
cosx=np.cos(x) # calculate cos(x)

########### Line style and Marker ###################
plt.plot(x,sinx, '*--r', label='sin')  
plt.plot(x,cosx, 'o-g', label='cos') 

############ Legend ####################
plt.legend(loc="best") #show legend

#### Lable and Grid ####################
plt.xlabel(r'$Radian$').set_fontsize(16) # x label 
plt.ylabel(r'$Amplitude$').set_fontsize(16) # y label
plt.grid() # show grid

plt.show()

# %%
#Subplots

############ Sin(x) ####################
x=np.linspace(-2*np.pi, 2*np.pi, 100) 
sinx=np.sin(x) # calculate sin(x)
cosx=np.cos(x) # calculate cos(x)

########### Subplot ###################
plt.subplot(2,1,1)
#Subplot command takes three parameters i.e. number of rows, numbers of columns and location of the plot.

plt.plot(x,sinx, '*--r', label='sin')
plt.grid() # show grid
plt.legend() #show legend
plt.xlabel(r'$Radian$')# x label 
plt.ylabel(r'$Amplitude$') # y label

plt.subplot(2,1,2)
plt.plot(x,cosx, 'o-g', label='cos') 
plt.grid() # show grid
plt.legend() #show legend
plt.xlabel(r'$Radian$') # x label 
plt.ylabel(r'$Amplitude$') # y label
############ Legend ####################

#### Lable and Grid ####################
plt.xlabel(r'$Radian$') # x label 
plt.ylabel(r'$Amplitude$') # y label


plt.show()

# %%
#exercise 1

#The NumPy linspace function (sometimes called np. linspace) is a tool in Python for creating numeric sequences.
#It's somewhat similar to the NumPy arange function, in that it 
#creates sequences of evenly spaced numbers structured as a NumPy array.

t= np.linspace(-np.pi,np.pi)


plt.plot(t,np.sin(t),marker='+',color='r')
plt.plot(t,np.cos(t),marker="^",color='g')

plt.title('sin and cos graph')
plt.xlabel("angle")
plt.ylabel("sin and cos")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#exercise 2

t= np.arange(0,4*np.pi,0.5)

plt.plot(t,np.sin(t),marker='+',color='r',linestyle = '-.')
plt.plot(t,np.cos(t),marker="^",color='g',linestyle= ":")

plt.title('sin and cos graph')
plt.xlabel("angle")
plt.ylabel("sin and cos")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#exercise 3
t=[0,30,45,60,90] # angles 

#converting degrees in radian as np.sin and cos takes angle in radian
#multplying pi/180

x=[i*(np.pi/180) for i in t] # list conprehention
#sin plot 

plt.plot(t,np.sin(x),marker='+',color='r')
#cos plot
plt.plot(t,np.cos(x),marker="^",color='g')

plt.xticks(t)

plt.title('sin and cos graph')

plt.xlabel("angle")

plt.ylabel("sin and cos")

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
